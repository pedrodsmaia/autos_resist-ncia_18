# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
dataset = pd.read_excel('autos_resist_18.xlsx')
dt = dataset

# %%
dataset.head()
# Out:
#         controle   ano      mes                                  titulo_do  \
# 0  68388041-2018  2018  janeiro  Morte por intervenção de agente do Estado
# 1  14048211-2018  2018  janeiro  Morte por intervenção de agente do Estado
# 2  31405111-2018  2018  janeiro  Morte por intervenção de agente do Estado
# 3  77590901-2018  2018  janeiro  Morte por intervenção de agente do Estado
# 4  07330961-2018  2018  janeiro  Morte por intervenção de agente do Estado
#
#                                    dp                 cisp  \
# 0  Delegacia de Homicídios da Capital     021a. Bonsucesso
# 1                      053a. Mesquita      055a. Queimados
# 2                      071a. Itaboraí       071a. Itaboraí
# 3                   165a. Mangaratiba    165a. Mangaratiba
# 4  Delegacia de Homicídios da Capital  017a. São Cristóvão
#
#                data_com             data_fato  hora_com hora_fato  \
# 0  2018-01-01T00:00:00Z  2018-01-01T00:00:00Z  11:40:24  07:00:00
# 1  2018-01-02T00:00:00Z  2018-01-02T00:00:00Z  23:47:26  18:30:00
# 2  2018-01-02T00:00:00Z  2018-01-02T00:00:00Z  15:36:07  12:05:00
# 3  2018-01-02T00:00:00Z  2018-01-02T00:00:00Z  17:59:18  18:00:00
# 4  2018-01-03T00:00:00Z  2018-01-03T00:00:00Z  10:58:45  05:50:00
#
#    municipio_fato                 local    cor
# 0  Rio de Janeiro              Ignorado  parda
# 1       Queimados                Favela  negra
# 2        Itaboraí           Via pública  parda
# 3     Mangaratiba           Via pública  parda
# 4  Rio de Janeiro  Interior de coletivo  negra

# %%
(     dataset["local"]
     .groupby(dataset["local"])
     .count()
     .sort_values(ascending=False)
     .plot(kind="barh")
)
#mortes no ano por local

# %%
pd.value_counts(dataset['cor'])
#cor de quem é mmorto
# Out:
# parda             737
# negra             401
# branca            226
# ignorado          147
# sem informação      5
# amarela             1
# Name: cor, dtype: int64

# %%
datameier=dataset.loc[dataset['cisp']=='023a. Meier']
display(datameier)
# Out:
#            controle   ano       mes  \
# 326   69801201-2018  2018     março
# 327   69801201-2018  2018     março
# 726   41482871-2018  2018     junho
# 1152  98318131-2018  2018  setembro
# 1181  88509231-2018  2018  setembro
#
#                                       titulo_do  \
# 326   Morte por intervenção de agente do Estado
# 327   Morte por intervenção de agente do Estado
# 726   Morte por intervenção de agente do Estado
# 1152  Morte por intervenção de agente do Estado
# 1181  Morte por intervenção de agente do Estado
#
#                                       dp         cisp              data_com  \
# 326   Delegacia de Homicídios da Capital  023a. Meier  2018-03-19T00:00:00Z
# 327   Delegacia de Homicídios da Capital  023a. Meier  2018-03-19T00:00:00Z
# 726   Delegacia de Homicídios da Capital  023a. Meier  2018-06-24T00:00:00Z
# 1152  Delegacia de Homicídios da Capital  023a. Meier  2018-09-19T00:00:00Z
# 1181  Delegacia de Homicídios da Capital  023a. Meier  2018-09-29T00:00:00Z
#
#                  data_fato  hora_com hora_fato  municipio_fato        local  \
# 326   2018-03-19T00:00:00Z  23:56:21  05:50:00  Rio de Janeiro  Via pública
# 327   2018-03-19T00:00:00Z  23:56:21  05:50:00  Rio de Janeiro  Via pública
# 726   2018-06-23T00:00:00Z  03:23:56  08:15:00  Rio de Janeiro  Via pública
# 1152  2018-09-19T00:00:00Z  08:06:00  05:00:00  Rio de Janeiro  Via pública
# 1181  2018-09-29T00:00:00Z  00:43:44  15:30:00  Rio de Janeiro  Via pública
#
#          cor
# 326    negra
# 327    negra
# 726    parda
# 1152   negra
# 1181  branca

# %%
datanegro=dataset.loc[dataset['cor']=='negra']
display(datanegro)
#os negros mortos pela PMERJ
# Out:
#            controle   ano       mes  \
# 1     14048211-2018  2018   janeiro
# 4     07330961-2018  2018   janeiro
# 9     75233171-2018  2018   janeiro
# 14    25182221-2018  2018   janeiro
# 16    25743261-2018  2018   janeiro
# 17    60573271-2018  2018   janeiro
# 18    85894612-2018  2018   janeiro
# 33    34518051-2018  2018   janeiro
# 34    48009841-2018  2018   janeiro
# 35    59514581-2018  2018   janeiro
# 38    92440611-2018  2018   janeiro
# 39    92454481-2018  2018   janeiro
# 40    99434391-2018  2018   janeiro
# 41    13491141-2018  2018   janeiro
# 43    16282551-2018  2018   janeiro
# 46    66225881-2018  2018   janeiro
# 56    79083631-2018  2018   janeiro
# 61    99138241-2018  2018   janeiro
# 70    14299411-2018  2018   janeiro
# 72    16177801-2018  2018   janeiro
# 91    22662101-2018  2018   janeiro
# 92    22662101-2018  2018   janeiro
# 94    65992381-2018  2018   janeiro
# 95    24306201-2018  2018   janeiro
# 97    48586271-2018  2018   janeiro
# 98    61379882-2018  2018   janeiro
# 109   30018431-2018  2018   janeiro
# 111   97952231-2018  2018   janeiro
# 112   03095511-2018  2018   janeiro
# 117   39361841-2018  2018   janeiro
# ...             ...   ...       ...
# 1416  01086181-2018  2018  novembro
# 1424  51093832-2018  2018  novembro
# 1433  13175251-2018  2018  novembro
# 1435  37715811-2018  2018  novembro
# 1450  25343651-2018  2018  dezembro
# 1451  25343651-2018  2018  dezembro
# 1452  50009751-2018  2018  dezembro
# 1453  60082651-2018  2018  dezembro
# 1456  64100031-2018  2018  dezembro
# 1458  18235441-2018  2018  dezembro
# 1460  76817711-2018  2018  dezembro
# 1461  07342381-2018  2018  dezembro
# 1466  10614431-2018  2018  dezembro
# 1468  19337571-2018  2018  dezembro
# 1470  32756781-2018  2018  dezembro
# 1471  68092051-2018  2018  dezembro
# 1480  48096361-2018  2018  dezembro
# 1494  78022801-2018  2018  dezembro
# 1495  58272331-2018  2018  dezembro
# 1496  50314892-2018  2018  dezembro
# 1502  00423381-2018  2018  dezembro
# 1505  03406942-2018  2018  dezembro
# 1509  49873841-2018  2018  dezembro
# 1510  93853901-2018  2018  dezembro
# 1522  70171261-2018  2018  dezembro
# 1523  58695001-2018  2018  dezembro
# 1525  88202211-2018  2018  dezembro
# 1526  09463851-2018  2018  dezembro
# 1529  39391961-2018  2018  dezembro
# 1531  03488311-2018  2018  dezembro
#
#                                       titulo_do  \
# 1     Morte por intervenção de agente do Estado
# 4     Morte por intervenção de agente do Estado
# 9     Morte por intervenção de agente do Estado
# 14    Morte por intervenção de agente do Estado
# 16    Morte por intervenção de agente do Estado
# 17    Morte por intervenção de agente do Estado
# 18    Morte por intervenção de agente do Estado
# 33    Morte por intervenção de agente do Estado
# 34    Morte por intervenção de agente do Estado
# 35    Morte por intervenção de agente do Estado
# 38    Morte por intervenção de agente do Estado
# 39    Morte por intervenção de agente do Estado
# 40    Morte por intervenção de agente do Estado
# 41    Morte por intervenção de agente do Estado
# 43    Morte por intervenção de agente do Estado
# 46    Morte por intervenção de agente do Estado
# 56    Morte por intervenção de agente do Estado
# 61    Morte por intervenção de agente do Estado
# 70    Morte por intervenção de agente do Estado
# 72    Morte por intervenção de agente do Estado
# 91    Morte por intervenção de agente do Estado
# 92    Morte por intervenção de agente do Estado
# 94    Morte por intervenção de agente do Estado
# 95    Morte por intervenção de agente do Estado
# 97    Morte por intervenção de agente do Estado
# 98    Morte por intervenção de agente do Estado
# 109   Morte por intervenção de agente do Estado
# 111   Morte por intervenção de agente do Estado
# 112   Morte por intervenção de agente do Estado
# 117   Morte por intervenção de agente do Estado
# ...                                         ...
# 1416  Morte por intervenção de agente do Estado
# 1424  Morte por intervenção de agente do Estado
# 1433  Morte por intervenção de agente do Estado
# 1435  Morte por intervenção de agente do Estado
# 1450  Morte por intervenção de agente do Estado
# 1451  Morte por intervenção de agente do Estado
# 1452  Morte por intervenção de agente do Estado
# 1453  Morte por intervenção de agente do Estado
# 1456  Morte por intervenção de agente do Estado
# 1458  Morte por intervenção de agente do Estado
# 1460  Morte por intervenção de agente do Estado
# 1461  Morte por intervenção de agente do Estado
# 1466  Morte por intervenção de agente do Estado
# 1468  Morte por intervenção de agente do Estado
# 1470  Morte por intervenção de agente do Estado
# 1471  Morte por intervenção de agente do Estado
# 1480  Morte por intervenção de agente do Estado
# 1494  Morte por intervenção de agente do Estado
# 1495  Morte por intervenção de agente do Estado
# 1496  Morte por intervenção de agente do Estado
# 1502  Morte por intervenção de agente do Estado
# 1505  Morte por intervenção de agente do Estado
# 1509  Morte por intervenção de agente do Estado
# 1510  Morte por intervenção de agente do Estado
# 1522  Morte por intervenção de agente do Estado
# 1523  Morte por intervenção de agente do Estado
# 1525  Morte por intervenção de agente do Estado
# 1526  Morte por intervenção de agente do Estado
# 1529  Morte por intervenção de agente do Estado
# 1531  Morte por intervenção de agente do Estado
#
#                                                     dp  \
# 1                                       053a. Mesquita
# 4                   Delegacia de Homicídios da Capital
# 9                   Delegacia de Homicídios da Capital
# 14                                         073a. Neves
# 16                                     074a. Alcantara
# 17                                    048a. Seropédica
# 18                                 151a. Nova Friburgo
# 33                                         058a. Posse
# 34                                         073a. Neves
# 35                               064a. Vilar dos Teles
# 38                                         058a. Posse
# 39       Delegacia de Homicídios da Baixada Fluminense
# 40                                      053a. Mesquita
# 41                               059a. Duque de Caxias
# 43                               059a. Duque de Caxias
# 46                          Central de Garantias Norte
# 56       Delegacia de Homicídios da Baixada Fluminense
# 61                          Central de Garantias Norte
# 70                  Delegacia de Homicídios da Capital
# 72                                      071a. Itaboraí
# 91                                      071a. Itaboraí
# 92                                      071a. Itaboraí
# 94                          Central de Garantias Norte
# 95                  Delegacia de Homicídios da Capital
# 97                               064a. Vilar dos Teles
# 98                               059a. Duque de Caxias
# 109                 Delegacia de Homicídios da Capital
# 111   Delegacia de Homicídios de Niterói e São Gonçalo
# 112                                  090a. Barra Mansa
# 117                     Delegacia de Combate às Drogas
# ...                                                ...
# 1416                                 075a. Rio do Ouro
# 1424                                 052a. Nova Iguaçu
# 1433                        Central de Garantias Norte
# 1435                Delegacia de Homicídios da Capital
# 1450                                035a. Campo Grande
# 1451                                035a. Campo Grande
# 1452                             059a. Duque de Caxias
# 1453     Delegacia de Homicídios da Baixada Fluminense
# 1456                                      063a. Japerí
# 1458                        Central de Garantias Norte
# 1460                                       034a. Bangu
# 1461                                     091a. Valença
# 1466                Delegacia de Homicídios da Capital
# 1468                                       073a. Neves
# 1470                Delegacia de Homicídios da Capital
# 1471  Delegacia de Homicídios de Niterói e São Gonçalo
# 1480                                     078a. Fonseca
# 1494                Delegacia de Homicídios da Capital
# 1495                Delegacia de Homicídios da Capital
# 1496                             059a. Duque de Caxias
# 1502                                035a. Campo Grande
# 1505                                054a. Belford Roxo
# 1509                Delegacia de Homicídios da Capital
# 1510                                       123a. Macaé
# 1522                Delegacia de Homicídios da Capital
# 1523                                       123a. Macaé
# 1525     Delegacia de Homicídios da Baixada Fluminense
# 1526  Delegacia de Homicídios de Niterói e São Gonçalo
# 1529                        Central de Garantias Norte
# 1531                                     089a. Resende
#
#                          cisp              data_com             data_fato  \
# 1             055a. Queimados  2018-01-02T00:00:00Z  2018-01-02T00:00:00Z
# 4         017a. São Cristóvão  2018-01-03T00:00:00Z  2018-01-03T00:00:00Z
# 9               011a. Rocinha  2018-01-03T00:00:00Z  2018-01-03T00:00:00Z
# 14          072a. São Gonçalo  2018-01-05T00:00:00Z  2018-01-05T00:00:00Z
# 16            074a. Alcantara  2018-01-05T00:00:00Z  2018-01-05T00:00:00Z
# 17            051a. Paracambí  2018-01-05T00:00:00Z  2018-01-05T00:00:00Z
# 18        151a. Nova Friburgo  2018-01-05T00:00:00Z  2018-01-05T00:00:00Z
# 33    056a. Comendador Soares  2018-01-11T00:00:00Z  2018-01-11T00:00:00Z
# 34                073a. Neves  2018-01-11T00:00:00Z  2018-01-11T00:00:00Z
# 35      064a. Vilar dos Teles  2018-01-11T00:00:00Z  2018-01-11T00:00:00Z
# 38                058a. Posse  2018-01-11T00:00:00Z  2018-01-11T00:00:00Z
# 39      064a. Vilar dos Teles  2018-01-11T00:00:00Z  2018-01-11T00:00:00Z
# 40    056a. Comendador Soares  2018-01-11T00:00:00Z  2018-01-11T00:00:00Z
# 41      059a. Duque de Caxias  2018-01-12T00:00:00Z  2018-01-12T00:00:00Z
# 43              062a. Imbariê  2018-01-12T00:00:00Z  2018-01-12T00:00:00Z
# 46               039a. Pavuna  2018-01-12T00:00:00Z  2018-01-12T00:00:00Z
# 56      064a. Vilar dos Teles  2018-01-13T00:00:00Z  2018-01-13T00:00:00Z
# 61      030a. Marechal Hermes  2018-01-14T00:00:00Z  2018-01-14T00:00:00Z
# 70      026a. Todos os Santos  2018-01-18T00:00:00Z  2018-01-17T00:00:00Z
# 72             071a. Itaboraí  2018-01-18T00:00:00Z  2018-01-17T00:00:00Z
# 91          075a. Rio do Ouro  2018-01-21T00:00:00Z  2018-01-21T00:00:00Z
# 92          075a. Rio do Ouro  2018-01-21T00:00:00Z  2018-01-21T00:00:00Z
# 94               039a. Pavuna  2018-01-21T00:00:00Z  2018-01-21T00:00:00Z
# 95               019a. Tijuca  2018-01-22T00:00:00Z  2018-01-22T00:00:00Z
# 97      064a. Vilar dos Teles  2018-01-22T00:00:00Z  2018-01-21T00:00:00Z
# 98       060a. Campos Elíseos  2018-01-22T00:00:00Z  2018-01-22T00:00:00Z
# 109             032a. Taquara  2018-01-24T00:00:00Z  2018-01-24T00:00:00Z
# 111            079a. Jurujuba  2018-01-24T00:00:00Z  2018-01-24T00:00:00Z
# 112         090a. Barra Mansa  2018-01-25T00:00:00Z  2018-01-25T00:00:00Z
# 117          021a. Bonsucesso  2018-01-25T00:00:00Z  2018-01-25T00:00:00Z
# ...                       ...                   ...                   ...
# 1416        075a. Rio do Ouro  2018-11-27T00:00:00Z  2018-11-27T00:00:00Z
# 1424  056a. Comendador Soares  2018-11-27T00:00:00Z  2018-11-26T00:00:00Z
# 1433             039a. Pavuna  2018-11-29T00:00:00Z  2018-11-29T00:00:00Z
# 1435         021a. Bonsucesso  2018-11-29T00:00:00Z  2018-11-29T00:00:00Z
# 1450              034a. Bangu  2018-12-03T00:00:00Z  2018-12-03T00:00:00Z
# 1451              034a. Bangu  2018-12-03T00:00:00Z  2018-12-03T00:00:00Z
# 1452    059a. Duque de Caxias  2018-12-03T00:00:00Z  2018-12-03T00:00:00Z
# 1453    064a. Vilar dos Teles  2018-12-03T00:00:00Z  2018-12-03T00:00:00Z
# 1456             063a. Japerí  2018-12-03T00:00:00Z  2018-12-03T00:00:00Z
# 1458    026a. Todos os Santos  2018-12-04T00:00:00Z  2018-12-04T00:00:00Z
# 1460              034a. Bangu  2018-12-04T00:00:00Z  2018-12-04T00:00:00Z
# 1461            091a. Valença  2018-12-05T00:00:00Z  2018-12-05T00:00:00Z
# 1466     040a. Honório Gurgel  2018-12-06T00:00:00Z  2018-12-06T00:00:00Z
# 1468        072a. São Gonçalo  2018-12-06T00:00:00Z  2018-12-06T00:00:00Z
# 1470          029a. Madureira  2018-12-06T00:00:00Z  2018-12-06T00:00:00Z
# 1471             077a. Icaraí  2018-12-06T00:00:00Z  2018-12-06T00:00:00Z
# 1480            078a. Fonseca  2018-12-10T00:00:00Z  2018-12-10T00:00:00Z
# 1494           028a. Campinho  2018-12-14T00:00:00Z  2018-12-13T00:00:00Z
# 1495            032a. Taquara  2018-12-15T00:00:00Z  2018-12-14T00:00:00Z
# 1496    059a. Duque de Caxias  2018-12-16T00:00:00Z  2018-12-16T00:00:00Z
# 1502              034a. Bangu  2018-12-20T00:00:00Z  2018-12-20T00:00:00Z
# 1505       054a. Belford Roxo  2018-12-22T00:00:00Z  2018-12-22T00:00:00Z
# 1509       025a. Engenho Novo  2018-12-22T00:00:00Z  2018-12-22T00:00:00Z
# 1510              123a. Macaé  2018-12-22T00:00:00Z  2018-12-22T00:00:00Z
# 1522              022a. Penha  2018-12-28T00:00:00Z  2018-12-28T00:00:00Z
# 1523              123a. Macaé  2018-12-29T00:00:00Z  2018-12-29T00:00:00Z
# 1525            062a. Imbariê  2018-12-29T00:00:00Z  2018-12-29T00:00:00Z
# 1526           079a. Jurujuba  2018-12-30T00:00:00Z  2018-12-30T00:00:00Z
# 1529             039a. Pavuna  2018-12-30T00:00:00Z  2018-12-30T00:00:00Z
# 1531            089a. Resende  2018-12-31T00:00:00Z  2018-12-31T00:00:00Z
#
#       hora_com hora_fato      municipio_fato                 local    cor
# 1     23:47:26  18:30:00           Queimados                Favela  negra
# 4     10:58:45  05:50:00      Rio de Janeiro  Interior de coletivo  negra
# 9     13:54:45  10:00:00      Rio de Janeiro           Via pública  negra
# 14    07:56:33  19:00:00         São Gonçalo           Via pública  negra
# 16    11:48:39  13:10:00         São Gonçalo                Favela  negra
# 17    22:41:06  17:00:00           Paracambi           Via pública  negra
# 18    09:08:11  16:00:00       Nova Friburgo           Via pública  negra
# 33    16:39:40  00:32:00         Nova Iguaçu           Via pública  negra
# 34    15:33:18  06:00:00         São Gonçalo           Via pública  negra
# 35    18:10:40  07:00:00  São João de Meriti           Via pública  negra
# 38    14:47:52  09:14:00         Nova Iguaçu                Outros  negra
# 39    11:07:50  22:00:00  São João de Meriti           Via pública  negra
# 40    03:26:26  00:05:00         Nova Iguaçu           Via pública  negra
# 41    20:34:56  08:00:00     Duque de Caxias           Via pública  negra
# 43    02:37:10  01:30:00     Duque de Caxias              Ignorado  negra
# 46    15:16:18  09:00:00      Rio de Janeiro                Favela  negra
# 56    00:12:59  17:45:00  São João de Meriti           Via pública  negra
# 61    17:01:08  19:45:00      Rio de Janeiro           Via pública  negra
# 70    00:42:52  21:00:00      Rio de Janeiro              Ignorado  negra
# 72    05:48:54  22:50:00            Itaboraí           Via pública  negra
# 91    22:04:06  09:00:00         São Gonçalo           Via pública  negra
# 92    22:04:06  09:00:00         São Gonçalo           Via pública  negra
# 94    02:37:50  20:00:00      Rio de Janeiro           Via pública  negra
# 95    11:27:23  06:00:00      Rio de Janeiro                Favela  negra
# 97    02:28:48  22:30:00  São João de Meriti           Via pública  negra
# 98    12:05:24  12:00:00     Duque de Caxias           Via pública  negra
# 109   23:26:06  14:30:00      Rio de Janeiro                Favela  negra
# 111   20:08:05  16:50:00             Niterói           Via pública  negra
# 112   23:43:55  06:00:00         Barra Mansa              Ignorado  negra
# 117   12:11:07  10:00:00      Rio de Janeiro                Favela  negra
# ...        ...       ...                 ...                   ...    ...
# 1416  19:42:56  15:40:00         São Gonçalo           Via pública  negra
# 1424  00:47:42  21:30:00         Nova Iguaçu           Via pública  negra
# 1433  02:19:52  20:30:00      Rio de Janeiro           Via pública  negra
# 1435  07:43:01  16:40:00      Rio de Janeiro           Via pública  negra
# 1450  22:58:21  11:00:00      Rio de Janeiro                Favela  negra
# 1451  22:58:21  11:00:00      Rio de Janeiro                Favela  negra
# 1452  08:33:51  08:30:00     Duque de Caxias           Via pública  negra
# 1453  00:04:01  13:40:00  São João de Meriti           Via pública  negra
# 1456  21:44:13  17:15:00              Japeri                Favela  negra
# 1458  21:57:16  15:30:00      Rio de Janeiro           Via pública  negra
# 1460  00:14:26  19:10:00      Rio de Janeiro           Via pública  negra
# 1461  11:48:20  09:45:00             Valença           Via pública  negra
# 1466  04:44:44  21:20:00      Rio de Janeiro           Via pública  negra
# 1468  05:39:01  19:30:00         São Gonçalo           Via pública  negra
# 1470  17:33:52  06:30:00      Rio de Janeiro           Via pública  negra
# 1471  23:19:39  13:10:00             Niterói                Favela  negra
# 1480  19:17:14  16:00:00             Niterói              Ignorado  negra
# 1494  03:05:31  20:30:00      Rio de Janeiro                Favela  negra
# 1495  04:32:48  23:40:00      Rio de Janeiro                Favela  negra
# 1496  17:31:57  05:50:00     Duque de Caxias           Via pública  negra
# 1502  03:45:56  00:10:00      Rio de Janeiro           Via pública  negra
# 1505  05:47:38  03:00:00        Belford Roxo           Via pública  negra
# 1509  07:36:50  05:00:00      Rio de Janeiro                Favela  negra
# 1510  14:02:08  00:00:00               Macaé           Via pública  negra
# 1522  16:30:31  12:40:00      Rio de Janeiro           Via pública  negra
# 1523  10:36:09  03:30:00               Macaé           Via pública  negra
# 1525  15:29:11  01:30:00     Duque de Caxias           Via pública  negra
# 1526  07:42:29  01:10:00             Niterói           Via pública  negra
# 1529  11:37:38  07:30:00      Rio de Janeiro           Via pública  negra
# 1531  20:02:27  12:00:00             Resende            Residência  negra
#
# [401 rows x 13 columns]

# %%
pd.value_counts(datanegro['cisp'])
#a cisp com maior contabilidade de morte de negros
# Out:
# 054a. Belford Roxo           26
# 039a. Pavuna                 21
# 059a. Duque de Caxias        18
# 060a. Campos Elíseos         17
# 063a. Japerí                 14
# 078a. Fonseca                14
# 075a. Rio do Ouro            13
# 025a. Engenho Novo           13
# 064a. Vilar dos Teles        13
# 056a. Comendador Soares      12
# 032a. Taquara                12
# 050a. Itaguaí                12
# 034a. Bangu                  12
# 072a. São Gonçalo             9
# 053a. Mesquita                9
# 074a. Alcantara               8
# 166a. Angra dos Reis          8
# 022a. Penha                   8
# 044a. Inhaúma                 8
# 021a. Bonsucesso              7
# 036a. Santa Cruz              7
# 055a. Queimados               7
# 062a. Imbariê                 7
# 073a. Neves                   6
# 058a. Posse                   6
# 071a. Itaboraí                6
# 123a. Macaé                   6
# 077a. Icaraí                  5
# 026a. Todos os Santos         5
# 079a. Jurujuba                5
#                              ..
# 066a. Piabetá                 2
# 134a. Campos                  2
# 052a. Nova Iguaçu             2
# 009a. Catete                  2
# 004a. Praça da República      2
# 038a. Braz de Pina            2
# 028a. Campinho                2
# 017a. São Cristóvão           2
# 024a. Piedade                 2
# 045a. Alemão                  2
# 065a. Magé                    2
# 090a. Barra Mansa             2
# 015a. Gávea                   1
# 035a. Campo Grande            1
# 033a. Realengo                1
# 091a. Valença                 1
# 057a. Nilópolis               1
# 089a. Resende                 1
# 119a. Rio Bonito              1
# 082a. Maricá                  1
# 108a. Três Rios               1
# 010a. Botafogo                1
# 027a. Vicente de Carvalho     1
# 007a. Santa Tereza            1
# 125a. São Pedro da Aldeia     1
# 151a. Nova Friburgo           1
# 037a. Ilha do Governador      1
# 127a. Búzios                  1
# 118a. Araruama                1
# 105a. Petrópolis              1
# Name: cisp, Length: 74, dtype: int64

# %%
pd.value_counts(datanegro['mes'])
#mês onde mais mataram negros
# Out:
# agosto       49
# maio         41
# julho        40
# junho        40
# outubro      38
# janeiro      38
# abril        29
# março        28
# setembro     28
# dezembro     26
# novembro     25
# fevereiro    19
# Name: mes, dtype: int64

# %%
pd.value_counts(datanegro['dp'])
# Out:
# Delegacia de Homicídios da Capital                  84
# 059a. Duque de Caxias                               33
# Central de Garantias Norte                          31
# 054a. Belford Roxo                                  24
# Delegacia de Homicídios de Niterói e São Gonçalo    22
# 053a. Mesquita                                      16
# Delegacia de Homicídios da Baixada Fluminense       15
# 052a. Nova Iguaçu                                   12
# 063a. Japerí                                        12
# 075a. Rio do Ouro                                   11
# 050a. Itaguaí                                       10
# 073a. Neves                                         10
# 071a. Itaboraí                                       9
# 166a. Angra dos Reis                                 8
# 034a. Bangu                                          8
# 074a. Alcantara                                      7
# 060a. Campos Elíseos                                 6
# 035a. Campo Grande                                   6
# 123a. Macaé                                          6
# 064a. Vilar dos Teles                                5
# 058a. Posse                                          5
# 072a. São Gonçalo                                    5
# 078a. Fonseca                                        4
# 048a. Seropédica                                     4
# 012a. Copacabana                                     4
# 126a. Cabo Frio                                      4
# 036a. Santa Cruz                                     4
# 093a. Volta Redonda                                  3
# Delegacia de Combate às Drogas                       3
# 110a. Teresópolis                                    3
# 055a. Queimados                                      3
# 118a. Araruama                                       2
# 090a. Barra Mansa                                    2
# 134a. Campos                                         2
# 051a. Paracambí                                      2
# 062a. Imbariê                                        2
# 039a. Pavuna                                         1
# 009a. Catete                                         1
# 091a. Valença                                        1
# 010a. Botafogo                                       1
# 151a. Nova Friburgo                                  1
# 056a. Comendador Soares                              1
# 127a. Búzios                                         1
# 079a. Jurujuba                                       1
# 105a. Petrópolis                                     1
# 089a. Resende                                        1
# 032a. Taquara                                        1
# 125a. São Pedro da Aldeia                            1
# 077a. Icaraí                                         1
# 108a. Três Rios                                      1
# Name: dp, dtype: int64

# %% [markdown]
# ## pd.value_counts(datanegro['dp'])]

# %%
datapardo=dataset.loc[dataset['cor']=='parda']
pd.value_counts(datapardo['cisp'])
#as cisps ccom maior números de mortes de pardos
# Out:
# 054a. Belford Roxo           40
# 059a. Duque de Caxias        38
# 056a. Comendador Soares      30
# 060a. Campos Elíseos         30
# 039a. Pavuna                 26
# 064a. Vilar dos Teles        26
# 050a. Itaguaí                23
# 073a. Neves                  21
# 032a. Taquara                21
# 063a. Japerí                 21
# 166a. Angra dos Reis         20
# 072a. São Gonçalo            20
# 074a. Alcantara              20
# 075a. Rio do Ouro            19
# 021a. Bonsucesso             18
# 062a. Imbariê                18
# 034a. Bangu                  18
# 055a. Queimados              17
# 025a. Engenho Novo           16
# 071a. Itaboraí               14
# 123a. Macaé                  12
# 038a. Braz de Pina           11
# 006a. Cidade Nova            11
# 040a. Honório Gurgel         11
# 041a. Tanque                 11
# 036a. Santa Cruz             11
# 017a. São Cristóvão          11
# 053a. Mesquita               10
# 011a. Rocinha                10
# 052a. Nova Iguaçu             9
#                              ..
# 004a. Praça da República      2
# 165a. Mangaratiba             2
# 121a. Casimiro de Abreu       2
# 081a. Itaipú                  2
# 028a. Campinho                2
# 048a. Seropédica              2
# 090a. Barra Mansa             2
# 016a. Barra da Tijuca         2
# 014a. Leblon                  2
# 007a. Santa Tereza            2
# 127a. Búzios                  1
# 134a. Campos                  1
# 019a. Tijuca                  1
# 018a. Praça da Bandeira       1
# 066a. Piabetá                 1
# 013a. Ipanema                 1
# 146a. Guarus                  1
# 132a. Arraial do Cabo         1
# 138a. Lajes de Muriaré        1
# 110a. Teresópolis             1
# 125a. São Pedro da Aldeia     1
# 020a. Grajaú                  1
# 043a. Pedra de Guaratiba      1
# 129a. Iguaba                  1
# 010a. Botafogo                1
# 070a. Tanguá                  1
# 093a. Volta Redonda           1
# 108a. Três Rios               1
# 023a. Meier                   1
# 061a. Xerém                   1
# Name: cisp, Length: 85, dtype: int64

# %%
pd.value_counts(datapardo['mes'])
#mês onde mais mataram pardos
# Out:
# agosto       82
# janeiro      78
# junho        75
# novembro     70
# maio         67
# julho        59
# setembro     59
# dezembro     53
# fevereiro    51
# outubro      51
# março        48
# abril        44
# Name: mes, dtype: int64

# %%
pd.value_counts(datapardo['dp'])
# Out:
# Delegacia de Homicídios da Capital                  165
# 059a. Duque de Caxias                                70
# Central de Garantias Norte                           46
# Delegacia de Homicídios da Baixada Fluminense        39
# 052a. Nova Iguaçu                                    33
# 054a. Belford Roxo                                   32
# Delegacia de Homicídios de Niterói e São Gonçalo     27
# 053a. Mesquita                                       26
# 073a. Neves                                          24
# 166a. Angra dos Reis                                 20
# 074a. Alcantara                                      19
# 072a. São Gonçalo                                    19
# 050a. Itaguaí                                        18
# 063a. Japerí                                         17
# 075a. Rio do Ouro                                    16
# 071a. Itaboraí                                       15
# 035a. Campo Grande                                   14
# 034a. Bangu                                          14
# 055a. Queimados                                      12
# 060a. Campos Elíseos                                 12
# 064a. Vilar dos Teles                                 9
# 126a. Cabo Frio                                       8
# 123a. Macaé                                           8
# 036a. Santa Cruz                                      8
# 048a. Seropédica                                      5
# 012a. Copacabana                                      4
# 128a. Rio das Ostras                                  4
# 118a. Araruama                                        4
# 062a. Imbariê                                         3
# 056a. Comendador Soares                               3
#                                                    ...
# 027a. Vicente de Carvalho                             2
# 078a. Fonseca                                         2
# Delegacia de Combate às Drogas                        2
# 165a. Mangaratiba                                     2
# 127a. Búzios                                          1
# 044a. Inhaúma                                         1
# 026a. Todos os Santos                                 1
# Delegacia de Roubos e Furtos de Automóveis            1
# 081a. Itaipú                                          1
# 134a. Campos                                          1
# 032a. Taquara                                         1
# 070a. Tanguá                                          1
# 108a. Três Rios                                       1
# 132a. Arraial do Cabo                                 1
# 058a. Posse                                           1
# 016a. Barra da Tijuca                                 1
# 061a. Xerém                                           1
# 146a. Guarus                                          1
# 129a. Iguaba                                          1
# 014a. Leblon                                          1
# 093a. Volta Redonda                                   1
# 041a. Tanque                                          1
# 005a. Mem de Sá                                       1
# 138a. Lajes de Muriaré                                1
# 125a. São Pedro da Aldeia                             1
# 025a. Engenho Novo                                    1
# 013a. Ipanema                                         1
# 010a. Botafogo                                        1
# 017a. São Cristóvão                                   1
# 110a. Teresópolis                                     1
# Name: dp, Length: 64, dtype: int64

# %% [markdown]
# dataset.count()
# #então ocorreram 1.534 mortes cometidas por policiais anos passado

# %%
pd.value_counts(dataset['cisp'])
#divisão das mortes por CISP
# Out:
# 054a. Belford Roxo          93
# 059a. Duque de Caxias       64
# 039a. Pavuna                63
# 056a. Comendador Soares     60
# 060a. Campos Elíseos        52
# 166a. Angra dos Reis        51
# 050a. Itaguaí               49
# 063a. Japerí                47
# 074a. Alcantara             45
# 064a. Vilar dos Teles       45
# 075a. Rio do Ouro           44
# 034a. Bangu                 43
# 072a. São Gonçalo           42
# 021a. Bonsucesso            39
# 032a. Taquara               37
# 073a. Neves                 35
# 071a. Itaboraí              34
# 025a. Engenho Novo          32
# 062a. Imbariê               30
# 055a. Queimados             27
# 078a. Fonseca               26
# 036a. Santa Cruz            25
# 022a. Penha                 23
# 053a. Mesquita              23
# 123a. Macaé                 22
# 040a. Honório Gurgel        20
# 126a. Cabo Frio             19
# 011a. Rocinha               19
# 044a. Inhaúma               18
# 038a. Braz de Pina          18
#                             ..
# 005a. Mem de Sá              4
# 165a. Mangaratiba            3
# 081a. Itaipú                 3
# 134a. Campos                 3
# 048a. Seropédica             3
# 124a. Saquarema              3
# 016a. Barra da Tijuca        3
# 010a. Botafogo               2
# 167a. Parati                 2
# 009a. Catete                 2
# 132a. Arraial do Cabo        2
# 146a. Guarus                 2
# 151a. Nova Friburgo          2
# 014a. Leblon                 2
# 108a. Três Rios              2
# 043a. Pedra de Guaratiba     1
# 091a. Valença                1
# 057a. Nilópolis              1
# 089a. Resende                1
# 138a. Lajes de Muriaré       1
# 099a. Itatiaia               1
# 105a. Petrópolis             1
# 013a. Ipanema                1
# 018a. Praça da Bandeira      1
# 129a. Iguaba                 1
# 119a. Rio Bonito             1
# 070a. Tanguá                 1
# 128a. Rio das Ostras         1
# 145a. São João da Barra      1
# 061a. Xerém                  1
# Name: cisp, Length: 97, dtype: int64

# %%
dp=pd.value_counts(dataset['dp'])
print(dp.to_string())
#divisão de mortes por DP
# Out:
# Delegacia de Homicídios da Capital                  327
# 059a. Duque de Caxias                               118
# Central de Garantias Norte                          108
# 054a. Belford Roxo                                   81
# Delegacia de Homicídios de Niterói e São Gonçalo     68
# 052a. Nova Iguaçu                                    65
# Delegacia de Homicídios da Baixada Fluminense        63
# 053a. Mesquita                                       51
# 166a. Angra dos Reis                                 50
# 073a. Neves                                          47
# 074a. Alcantara                                      42
# 071a. Itaboraí                                       39
# 075a. Rio do Ouro                                    37
# 063a. Japerí                                         37
# 050a. Itaguaí                                        35
# 072a. São Gonçalo                                    33
# 035a. Campo Grande                                   29
# 034a. Bangu                                          28
# 060a. Campos Elíseos                                 19
# 123a. Macaé                                          18
# 126a. Cabo Frio                                      18
# 048a. Seropédica                                     18
# 064a. Vilar dos Teles                                18
# 036a. Santa Cruz                                     17
# 055a. Queimados                                      16
# 012a. Copacabana                                     10
# 093a. Volta Redonda                                   8
# 078a. Fonseca                                         7
# 062a. Imbariê                                         7
# 118a. Araruama                                        7
# 058a. Posse                                           7
# Delegacia de Combate às Drogas                        7
# 128a. Rio das Ostras                                  5
# 033a. Realengo                                        5
# 022a. Penha                                           5
# 056a. Comendador Soares                               5
# 121a. Casimiro de Abreu                               5
# 165a. Mangaratiba                                     4
# 110a. Teresópolis                                     4
# 090a. Barra Mansa                                     4
# 125a. São Pedro da Aldeia                             4
# 127a. Búzios                                          4
# 146a. Guarus                                          3
# 132a. Arraial do Cabo                                 3
# 134a. Campos                                          3
# 005a. Mem de Sá                                       3
# 016a. Barra da Tijuca                                 3
# 079a. Jurujuba                                        3
# 051a. Paracambí                                       2
# 108a. Três Rios                                       2
# 027a. Vicente de Carvalho                             2
# 032a. Taquara                                         2
# 010a. Botafogo                                        2
# 151a. Nova Friburgo                                   2
# 167a. Parati                                          2
# 017a. São Cristóvão                                   1
# 021a. Bonsucesso                                      1
# 081a. Itaipú                                          1
# 129a. Iguaba                                          1
# 009a. Catete                                          1
# 099a. Itatiaia                                        1
# Delegacia de Roubos e Furtos de Automóveis            1
# 014a. Leblon                                          1
# 041a. Tanque                                          1
# 039a. Pavuna                                          1
# 089a. Resende                                         1
# 065a. Magé                                            1
# 025a. Engenho Novo                                    1
# 061a. Xerém                                           1
# 077a. Icaraí                                          1
# 013a. Ipanema                                         1
# 105a. Petrópolis                                      1
# 070a. Tanguá                                          1
# 138a. Lajes de Muriaré                                1
# 026a. Todos os Santos                                 1
# 044a. Inhaúma                                         1
# 091a. Valença                                         1

# %%
dp.to_csv('total_dp.csv')

# %%
dp('rows')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-24e8893786e5> in <module>()
# ----> 1 dp('rows')
#
# TypeError: 'Series' object is not callable

# %%
pd.value_counts(dataset['mes'])
#Do ano todo, consegui a quantidade de autos de resistência cometidos a cada mês
# Out:
# agosto       176
# janeiro      157
# junho        155
# maio         145
# novembro     136
# julho        130
# outubro      127
# março        109
# setembro     108
# fevereiro    102
# abril        101
# dezembro      88
# Name: mes, dtype: int64

# %%
pd.value_counts(dataset['data_com'])
#a distribuição dos autos de resistência pelos dias do ano
# Out:
# 2018-08-02T00:00:00Z    18
# 2018-08-20T00:00:00Z    17
# 2018-08-15T00:00:00Z    16
# 2018-05-19T00:00:00Z    15
# 2018-11-27T00:00:00Z    14
# 2018-09-13T00:00:00Z    13
# 2018-01-25T00:00:00Z    12
# 2018-06-24T00:00:00Z    12
# 2018-08-16T00:00:00Z    11
# 2018-04-05T00:00:00Z    11
# 2018-01-19T00:00:00Z    11
# 2018-01-31T00:00:00Z    11
# 2018-02-26T00:00:00Z    11
# 2018-05-22T00:00:00Z    11
# 2018-02-16T00:00:00Z    10
# 2018-12-03T00:00:00Z    10
# 2018-05-09T00:00:00Z     9
# 2018-06-10T00:00:00Z     9
# 2018-10-10T00:00:00Z     9
# 2018-08-24T00:00:00Z     9
# 2018-01-11T00:00:00Z     9
# 2018-08-27T00:00:00Z     9
# 2018-07-18T00:00:00Z     9
# 2018-06-20T00:00:00Z     9
# 2018-05-30T00:00:00Z     9
# 2018-01-12T00:00:00Z     9
# 2018-04-20T00:00:00Z     8
# 2018-08-21T00:00:00Z     8
# 2018-09-27T00:00:00Z     8
# 2018-11-23T00:00:00Z     8
#                         ..
# 2018-08-17T00:00:00Z     1
# 2018-07-16T00:00:00Z     1
# 2018-05-28T00:00:00Z     1
# 2018-02-09T00:00:00Z     1
# 2018-10-14T00:00:00Z     1
# 2018-09-28T00:00:00Z     1
# 2018-04-19T00:00:00Z     1
# 2018-05-02T00:00:00Z     1
# 2018-09-30T00:00:00Z     1
# 2018-12-23T00:00:00Z     1
# 2018-10-12T00:00:00Z     1
# 2018-12-08T00:00:00Z     1
# 2018-02-20T00:00:00Z     1
# 2018-02-12T00:00:00Z     1
# 2018-08-23T00:00:00Z     1
# 2018-10-26T00:00:00Z     1
# 2018-09-29T00:00:00Z     1
# 2018-03-05T00:00:00Z     1
# 2018-09-12T00:00:00Z     1
# 2018-10-24T00:00:00Z     1
# 2018-03-11T00:00:00Z     1
# 2018-02-14T00:00:00Z     1
# 2018-07-01T00:00:00Z     1
# 2018-01-09T00:00:00Z     1
# 2018-03-26T00:00:00Z     1
# 2018-03-18T00:00:00Z     1
# 2018-01-15T00:00:00Z     1
# 2018-02-19T00:00:00Z     1
# 2018-02-27T00:00:00Z     1
# 2018-04-02T00:00:00Z     1
# Name: data_com, Length: 343, dtype: int64

# %%
df = pd.read_excel('ttl_mes.xlsx')
display(df)
# Out:
#           Mês  Total
# 0     janeiro    157
# 1   fevereiro    102
# 2       março    109
# 3       abril    101
# 4        maio    145
# 5       junho    155
# 6       julho    130
# 7      agosto    176
# 8    setembro    108
# 9     outubro    127
# 10   novembro    136
# 11   dezembro     88

# %%
df.plot(kind='barh')

# %%
df.plot()

# %%
pd.value_counts(dataset['mes'])
dataset2=pd.value_counts(dataset['mes'])
#fiz um novo dataset chamado dataset2 com a quantidade de autos por mês para analisar

# %%
mes=dataset2.sort_values()
#lista dos meses em ordem crescente pela quantidade de autos de resistência

# %%
mes.plot(kind='barh')
#plotei os dados em um gráfico de barras

# %%
dataset3=dataset.loc[dataset['mes']=='janeiro']
dataset3.head()
#destaco o mês de janeiro
# Out:
#         controle   ano      mes                                  titulo_do  \
# 0  68388041-2018  2018  janeiro  Morte por intervenção de agente do Estado
# 1  14048211-2018  2018  janeiro  Morte por intervenção de agente do Estado
# 2  31405111-2018  2018  janeiro  Morte por intervenção de agente do Estado
# 3  77590901-2018  2018  janeiro  Morte por intervenção de agente do Estado
# 4  07330961-2018  2018  janeiro  Morte por intervenção de agente do Estado
#
#                                    dp                 cisp  \
# 0  Delegacia de Homicídios da Capital     021a. Bonsucesso
# 1                      053a. Mesquita      055a. Queimados
# 2                      071a. Itaboraí       071a. Itaboraí
# 3                   165a. Mangaratiba    165a. Mangaratiba
# 4  Delegacia de Homicídios da Capital  017a. São Cristóvão
#
#                data_com             data_fato  hora_com hora_fato  \
# 0  2018-01-01T00:00:00Z  2018-01-01T00:00:00Z  11:40:24  07:00:00
# 1  2018-01-02T00:00:00Z  2018-01-02T00:00:00Z  23:47:26  18:30:00
# 2  2018-01-02T00:00:00Z  2018-01-02T00:00:00Z  15:36:07  12:05:00
# 3  2018-01-02T00:00:00Z  2018-01-02T00:00:00Z  17:59:18  18:00:00
# 4  2018-01-03T00:00:00Z  2018-01-03T00:00:00Z  10:58:45  05:50:00
#
#    municipio_fato                 local    cor
# 0  Rio de Janeiro              Ignorado  parda
# 1       Queimados                Favela  negra
# 2        Itaboraí           Via pública  parda
# 3     Mangaratiba           Via pública  parda
# 4  Rio de Janeiro  Interior de coletivo  negra

# %%
pd.value_counts(dataset3['data_com'])
#dias com mais autos de resistência em janeiro
# Out:
# 2018-01-25T00:00:00Z    12
# 2018-01-19T00:00:00Z    11
# 2018-01-31T00:00:00Z    11
# 2018-01-11T00:00:00Z     9
# 2018-01-12T00:00:00Z     9
# 2018-01-30T00:00:00Z     8
# 2018-01-23T00:00:00Z     7
# 2018-01-03T00:00:00Z     7
# 2018-01-13T00:00:00Z     7
# 2018-01-05T00:00:00Z     6
# 2018-01-17T00:00:00Z     5
# 2018-01-18T00:00:00Z     5
# 2018-01-20T00:00:00Z     5
# 2018-01-22T00:00:00Z     5
# 2018-01-24T00:00:00Z     5
# 2018-01-08T00:00:00Z     5
# 2018-01-14T00:00:00Z     5
# 2018-01-21T00:00:00Z     4
# 2018-01-06T00:00:00Z     4
# 2018-01-29T00:00:00Z     4
# 2018-01-28T00:00:00Z     4
# 2018-01-27T00:00:00Z     3
# 2018-01-26T00:00:00Z     3
# 2018-01-02T00:00:00Z     3
# 2018-01-04T00:00:00Z     3
# 2018-01-16T00:00:00Z     2
# 2018-01-01T00:00:00Z     1
# 2018-01-09T00:00:00Z     1
# 2018-01-15T00:00:00Z     1
# 2018-01-10T00:00:00Z     1
# 2018-01-07T00:00:00Z     1
# Name: data_com, dtype: int64

# %%
pd.value_counts(dataset3['cisp'])
#a quantidade de autos de reistência em janeiro, divido por bairro
# Out:
# 021a. Bonsucesso             12
# 074a. Alcantara              10
# 039a. Pavuna                  9
# 011a. Rocinha                 8
# 064a. Vilar dos Teles         7
# 017a. São Cristóvão           6
# 166a. Angra dos Reis          6
# 060a. Campos Elíseos          6
# 032a. Taquara                 6
# 044a. Inhaúma                 4
# 030a. Marechal Hermes         4
# 059a. Duque de Caxias         4
# 056a. Comendador Soares       4
# 071a. Itaboraí                4
# 072a. São Gonçalo             4
# 036a. Santa Cruz              3
# 038a. Braz de Pina            3
# 006a. Cidade Nova             3
# 073a. Neves                   3
# 124a. Saquarema               3
# 054a. Belford Roxo            3
# 058a. Posse                   3
# 063a. Japerí                  3
# 062a. Imbariê                 3
# 026a. Todos os Santos         2
# 065a. Magé                    2
# 075a. Rio do Ouro             2
# 050a. Itaguaí                 2
# 025a. Engenho Novo            2
# 132a. Arraial do Cabo         2
# 034a. Bangu                   2
# 033a. Realengo                1
# 108a. Três Rios               1
# 123a. Macaé                   1
# 029a. Madureira               1
# 151a. Nova Friburgo           1
# 093a. Volta Redonda           1
# 167a. Parati                  1
# 090a. Barra Mansa             1
# 079a. Jurujuba                1
# 061a. Xerém                   1
# 024a. Piedade                 1
# 082a. Maricá                  1
# 078a. Fonseca                 1
# 165a. Mangaratiba             1
# 076a. Niterói - Centro        1
# 051a. Paracambí               1
# 028a. Campinho                1
# 012a. Copacabana              1
# 019a. Tijuca                  1
# 055a. Queimados               1
# 041a. Tanque                  1
# 031a. Ricardo Albuquerque     1
# Name: cisp, dtype: int64

# %%
pd.value_counts(dataset3['cor'])
#autos de resistência em janeiro por cor
# Out:
# parda       78
# negra       38
# branca      27
# ignorado    13
# Name: cor, dtype: int64

# %%
pd.value_counts(dataset3['local'])
#autos de resistiência em janeiro por local
# Out:
# Via pública             103
# Favela                   30
# Ignorado                 10
# Outros                    7
# Floresta                  2
# Interior de coletivo      2
# Morro                     1
# Residência                1
# Hospital                  1
# Name: local, dtype: int64

# %%
bs=dataset3.loc[dataset3['cisp']=='021a. Bonsucesso']
display(bs)
#autos de resistência cometidos somente em Bonsucesso
# Out:
#           controle   ano      mes                                  titulo_do  \
# 0    68388041-2018  2018  janeiro  Morte por intervenção de agente do Estado
# 113  14963581-2018  2018  janeiro  Morte por intervenção de agente do Estado
# 116  39361841-2018  2018  janeiro  Morte por intervenção de agente do Estado
# 117  39361841-2018  2018  janeiro  Morte por intervenção de agente do Estado
# 118  39361841-2018  2018  janeiro  Morte por intervenção de agente do Estado
# 119  39361841-2018  2018  janeiro  Morte por intervenção de agente do Estado
# 130  47833971-2018  2018  janeiro  Morte por intervenção de agente do Estado
# 131  47833971-2018  2018  janeiro  Morte por intervenção de agente do Estado
# 134  09760091-2018  2018  janeiro  Morte por intervenção de agente do Estado
# 138  23663531-2018  2018  janeiro  Morte por intervenção de agente do Estado
# 139  23663531-2018  2018  janeiro  Morte por intervenção de agente do Estado
# 140  23663531-2018  2018  janeiro  Morte por intervenção de agente do Estado
#
#                                      dp              cisp  \
# 0    Delegacia de Homicídios da Capital  021a. Bonsucesso
# 113  Delegacia de Homicídios da Capital  021a. Bonsucesso
# 116      Delegacia de Combate às Drogas  021a. Bonsucesso
# 117      Delegacia de Combate às Drogas  021a. Bonsucesso
# 118      Delegacia de Combate às Drogas  021a. Bonsucesso
# 119      Delegacia de Combate às Drogas  021a. Bonsucesso
# 130  Delegacia de Homicídios da Capital  021a. Bonsucesso
# 131  Delegacia de Homicídios da Capital  021a. Bonsucesso
# 134  Delegacia de Homicídios da Capital  021a. Bonsucesso
# 138  Delegacia de Homicídios da Capital  021a. Bonsucesso
# 139  Delegacia de Homicídios da Capital  021a. Bonsucesso
# 140  Delegacia de Homicídios da Capital  021a. Bonsucesso
#
#                  data_com             data_fato  hora_com hora_fato  \
# 0    2018-01-01T00:00:00Z  2018-01-01T00:00:00Z  11:40:24  07:00:00
# 113  2018-01-25T00:00:00Z  2018-01-25T00:00:00Z  18:59:54  09:00:00
# 116  2018-01-25T00:00:00Z  2018-01-25T00:00:00Z  12:11:07  10:00:00
# 117  2018-01-25T00:00:00Z  2018-01-25T00:00:00Z  12:11:07  10:00:00
# 118  2018-01-25T00:00:00Z  2018-01-25T00:00:00Z  12:11:07  10:00:00
# 119  2018-01-25T00:00:00Z  2018-01-25T00:00:00Z  12:11:07  10:00:00
# 130  2018-01-28T00:00:00Z  2018-01-28T00:00:00Z  23:11:47  18:40:00
# 131  2018-01-28T00:00:00Z  2018-01-28T00:00:00Z  23:11:47  18:40:00
# 134  2018-01-29T00:00:00Z  2018-01-29T00:00:00Z  12:46:40  03:00:00
# 138  2018-01-30T00:00:00Z  2018-01-30T00:00:00Z  17:22:56  08:00:00
# 139  2018-01-30T00:00:00Z  2018-01-30T00:00:00Z  17:22:56  08:00:00
# 140  2018-01-30T00:00:00Z  2018-01-30T00:00:00Z  17:22:56  08:00:00
#
#      municipio_fato        local       cor
# 0    Rio de Janeiro     Ignorado     parda
# 113  Rio de Janeiro  Via pública     parda
# 116  Rio de Janeiro       Favela  ignorado
# 117  Rio de Janeiro       Favela     negra
# 118  Rio de Janeiro       Favela    branca
# 119  Rio de Janeiro       Favela     negra
# 130  Rio de Janeiro  Via pública     parda
# 131  Rio de Janeiro  Via pública     parda
# 134  Rio de Janeiro     Ignorado     parda
# 138  Rio de Janeiro  Via pública    branca
# 139  Rio de Janeiro  Via pública    branca
# 140  Rio de Janeiro  Via pública     parda

# %%
pd.value_counts(bs['cor'])
#cor de quem morreu em Bonsucesso em janeiro
# Out:
# parda       6
# branca      3
# negra       2
# ignorado    1
# Name: cor, dtype: int64

# %%
pd.value_counts(bs['local'])
#local de quem foi morto em Bonsucesso em Janeiro
# Out:
# Via pública    6
# Favela         4
# Ignorado       2
# Name: local, dtype: int64

# %%
pd.value_counts(bs['data_com'])
#autos de reistência em Bonsucesso em Janeiro por data computada
# Out:
# 2018-01-25T00:00:00Z    5
# 2018-01-30T00:00:00Z    3
# 2018-01-28T00:00:00Z    2
# 2018-01-01T00:00:00Z    1
# 2018-01-29T00:00:00Z    1
# Name: data_com, dtype: int64

# %%
pd.value_counts(bs['hora_fato'])
#hora dos autos de resistência em Bonsucesso em Janeiro
# Out:
# 10:00:00    4
# 08:00:00    3
# 18:40:00    2
# 09:00:00    1
# 07:00:00    1
# 03:00:00    1
# Name: hora_fato, dtype: int64

# %%
dataset4=dataset.loc[dataset['mes']=='fevereiro']
dataset4.head()
#separei o mês de fevereiro
# Out:
#           controle   ano        mes  \
# 157  20762971-2018  2018  fevereiro
# 158  62313841-2018  2018  fevereiro
# 159  30685641-2018  2018  fevereiro
# 160  30685641-2018  2018  fevereiro
# 161  58324821-2018  2018  fevereiro
#
#                                      titulo_do  \
# 157  Morte por intervenção de agente do Estado
# 158  Morte por intervenção de agente do Estado
# 159  Morte por intervenção de agente do Estado
# 160  Morte por intervenção de agente do Estado
# 161  Morte por intervenção de agente do Estado
#
#                                  dp                  cisp  \
# 157  Delegacia de Combate às Drogas    054a. Belford Roxo
# 158               075a. Rio do Ouro     075a. Rio do Ouro
# 159            166a. Angra dos Reis  166a. Angra dos Reis
# 160            166a. Angra dos Reis  166a. Angra dos Reis
# 161                  053a. Mesquita       055a. Queimados
#
#                  data_com             data_fato  hora_com hora_fato  \
# 157  2018-02-01T00:00:00Z  2018-02-01T00:00:00Z  11:33:40  08:00:00
# 158  2018-02-01T00:00:00Z  2018-02-01T00:00:00Z  15:01:49  14:00:00
# 159  2018-02-02T00:00:00Z  2018-02-02T00:00:00Z  12:12:24  07:00:00
# 160  2018-02-02T00:00:00Z  2018-02-02T00:00:00Z  12:12:24  07:00:00
# 161  2018-02-02T00:00:00Z  2018-02-02T00:00:00Z  05:20:40  00:45:00
#
#      municipio_fato        local    cor
# 157    Belford Roxo   Residência  negra
# 158     São Gonçalo  Via pública  parda
# 159  Angra dos Reis  Via pública  parda
# 160  Angra dos Reis  Via pública  parda
# 161       Queimados  Via pública  parda

# %%
pd.value_counts(dataset4['cisp'])
#a divisão de autos de resistência de fevereiro por cisps
# Out:
# 075a. Rio do Ouro            7
# 050a. Itaguaí                7
# 039a. Pavuna                 6
# 054a. Belford Roxo           5
# 060a. Campos Elíseos         5
# 056a. Comendador Soares      5
# 073a. Neves                  5
# 064a. Vilar dos Teles        4
# 058a. Posse                  4
# 071a. Itaboraí               3
# 166a. Angra dos Reis         3
# 072a. São Gonçalo            3
# 066a. Piabetá                3
# 034a. Bangu                  3
# 063a. Japerí                 3
# 074a. Alcantara              2
# 017a. São Cristóvão          2
# 024a. Piedade                2
# 025a. Engenho Novo           2
# 028a. Campinho               2
# 032a. Taquara                1
# 055a. Queimados              1
# 053a. Mesquita               1
# 027a. Vicente de Carvalho    1
# 040a. Honório Gurgel         1
# 044a. Inhaúma                1
# 110a. Teresópolis            1
# 059a. Duque de Caxias        1
# 090a. Barra Mansa            1
# 011a. Rocinha                1
# 031a. Ricardo Albuquerque    1
# 123a. Macaé                  1
# 129a. Iguaba                 1
# 076a. Niterói - Centro       1
# 065a. Magé                   1
# 126a. Cabo Frio              1
# 045a. Alemão                 1
# 015a. Gávea                  1
# 077a. Icaraí                 1
# 062a. Imbariê                1
# 052a. Nova Iguaçu            1
# 038a. Braz de Pina           1
# 036a. Santa Cruz             1
# 093a. Volta Redonda          1
# 082a. Maricá                 1
# 125a. São Pedro da Aldeia    1
# Name: cisp, dtype: int64

# %%
pd.value_counts(dataset4['data_fato'])
#a divisão dos autos de fevereiro por dias
# Out:
# 2018-02-26T00:00:00Z    11
# 2018-02-02T00:00:00Z     9
# 2018-02-16T00:00:00Z     7
# 2018-02-05T00:00:00Z     7
# 2018-02-08T00:00:00Z     7
# 2018-02-15T00:00:00Z     6
# 2018-02-01T00:00:00Z     5
# 2018-02-22T00:00:00Z     5
# 2018-02-07T00:00:00Z     5
# 2018-02-18T00:00:00Z     5
# 2018-02-17T00:00:00Z     4
# 2018-02-03T00:00:00Z     4
# 2018-02-28T00:00:00Z     4
# 2018-02-23T00:00:00Z     3
# 2018-02-24T00:00:00Z     3
# 2018-02-04T00:00:00Z     3
# 2018-02-13T00:00:00Z     2
# 2018-02-09T00:00:00Z     2
# 2018-02-19T00:00:00Z     2
# 2018-02-21T00:00:00Z     2
# 2018-02-27T00:00:00Z     1
# 2018-02-12T00:00:00Z     1
# 2018-02-11T00:00:00Z     1
# 2018-02-14T00:00:00Z     1
# 2018-02-06T00:00:00Z     1
# 2018-02-10T00:00:00Z     1
# Name: data_fato, dtype: int64

# %%
pd.value_counts(dataset4['cor'])
#a cor de quem mais foi morto pela polícia em fevereiro
# Out:
# parda             51
# branca            22
# negra             19
# ignorado           9
# sem informação     1
# Name: cor, dtype: int64

# %%
pd.value_counts(dataset4['local'])
#local de quem mais morreu em fevereiro
# Out:
# Via pública    78
# Favela         11
# Residência      6
# Morro           4
# Ignorado        2
# Outros          1
# Name: local, dtype: int64

# %%
dataset8=dataset.loc[dataset['mes']=='março']
dataset8.head()
# Out:
#           controle   ano    mes                                  titulo_do  \
# 253  21515161-2018  2018  março  Morte por intervenção de agente do Estado
# 254  21515161-2018  2018  março  Morte por intervenção de agente do Estado
# 255  32613811-2018  2018  março  Morte por intervenção de agente do Estado
# 256  78436641-2018  2018  março  Morte por intervenção de agente do Estado
# 257  92576391-2018  2018  março  Morte por intervenção de agente do Estado
#
#                                                    dp                   cisp  \
# 253                             059a. Duque de Caxias  059a. Duque de Caxias
# 254                             059a. Duque de Caxias  059a. Duque de Caxias
# 255  Delegacia de Homicídios de Niterói e São Gonçalo           077a. Icaraí
# 256     Delegacia de Homicídios da Baixada Fluminense  064a. Vilar dos Teles
# 257     Delegacia de Homicídios da Baixada Fluminense  064a. Vilar dos Teles
#
#                  data_com             data_fato  hora_com hora_fato  \
# 253  2018-03-01T00:00:00Z  2018-03-01T00:00:00Z  19:16:20  12:30:00
# 254  2018-03-01T00:00:00Z  2018-03-01T00:00:00Z  19:16:20  12:30:00
# 255  2018-03-01T00:00:00Z  2018-03-01T00:00:00Z  15:57:15  17:15:00
# 256  2018-03-01T00:00:00Z  2018-03-01T00:00:00Z  10:00:08  20:30:00
# 257  2018-03-01T00:00:00Z  2018-03-01T00:00:00Z  22:41:18  17:30:00
#
#          municipio_fato        local    cor
# 253     Duque de Caxias  Via pública  parda
# 254     Duque de Caxias  Via pública  parda
# 255             Niterói  Via pública  parda
# 256  São João de Meriti  Via pública  negra
# 257  São João de Meriti       Favela  parda

# %%
pd.value_counts(dataset8['cisp'])
#a divisão de autos de resistência de março por CISP
# Out:
# 064a. Vilar dos Teles        8
# 011a. Rocinha                7
# 073a. Neves                  7
# 056a. Comendador Soares      7
# 055a. Queimados              5
# 031a. Ricardo Albuquerque    3
# 053a. Mesquita               3
# 027a. Vicente de Carvalho    3
# 072a. São Gonçalo            3
# 123a. Macaé                  3
# 028a. Campinho               3
# 060a. Campos Elíseos         3
# 059a. Duque de Caxias        3
# 036a. Santa Cruz             3
# 038a. Braz de Pina           3
# 050a. Itaguaí                3
# 029a. Madureira              2
# 065a. Magé                   2
# 023a. Meier                  2
# 054a. Belford Roxo           2
# 074a. Alcantara              2
# 039a. Pavuna                 2
# 126a. Cabo Frio              2
# 063a. Japerí                 2
# 062a. Imbariê                2
# 034a. Bangu                  2
# 071a. Itaboraí               2
# 093a. Volta Redonda          1
# 128a. Rio das Ostras         1
# 082a. Maricá                 1
# 021a. Bonsucesso             1
# 037a. Ilha do Governador     1
# 166a. Angra dos Reis         1
# 057a. Nilópolis              1
# 077a. Icaraí                 1
# 025a. Engenho Novo           1
# 090a. Barra Mansa            1
# 040a. Honório Gurgel         1
# 118a. Araruama               1
# 041a. Tanque                 1
# 017a. São Cristóvão          1
# 030a. Marechal Hermes        1
# 019a. Tijuca                 1
# 012a. Copacabana             1
# 078a. Fonseca                1
# 024a. Piedade                1
# 016a. Barra da Tijuca        1
# Name: cisp, dtype: int64

# %%
dataset5=dataset.loc[dataset['mes']=='agosto']
dataset5.head()
#separa só o mês de agosto
# Out:
#           controle   ano     mes                                  titulo_do  \
# 898  07479201-2018  2018  agosto  Morte por intervenção de agente do Estado
# 899  27186871-2018  2018  agosto  Morte por intervenção de agente do Estado
# 900  27186871-2018  2018  agosto  Morte por intervenção de agente do Estado
# 901  64144721-2018  2018  agosto  Morte por intervenção de agente do Estado
# 902  80827191-2018  2018  agosto  Morte por intervenção de agente do Estado
#
#                                      dp                cisp  \
# 898                     126a. Cabo Frio     126a. Cabo Frio
# 899  Delegacia de Homicídios da Capital       044a. Inhaúma
# 900  Delegacia de Homicídios da Capital       044a. Inhaúma
# 901  Delegacia de Homicídios da Capital  038a. Braz de Pina
# 902                         123a. Macaé         123a. Macaé
#
#                  data_com             data_fato  hora_com hora_fato  \
# 898  2018-08-01T00:00:00Z  2018-07-31T00:00:00Z  12:13:54  22:30:00
# 899  2018-08-01T00:00:00Z  2018-08-01T00:00:00Z  09:14:50  06:30:00
# 900  2018-08-01T00:00:00Z  2018-08-01T00:00:00Z  09:14:50  06:30:00
# 901  2018-08-01T00:00:00Z  2018-08-01T00:00:00Z  19:24:24  06:40:00
# 902  2018-08-01T00:00:00Z  2018-08-01T00:00:00Z  02:14:01  22:30:00
#
#      municipio_fato        local    cor
# 898       Cabo Frio  Via pública  parda
# 899  Rio de Janeiro  Via pública  parda
# 900  Rio de Janeiro  Via pública  parda
# 901  Rio de Janeiro  Via pública  parda
# 902           Macaé       Favela  negra

# %%
pd.value_counts(dataset5['cisp'])
#quantidade de autos em agosto por CISP
# Out:
# 054a. Belford Roxo           18
# 071a. Itaboraí                9
# 078a. Fonseca                 8
# 059a. Duque de Caxias         7
# 166a. Angra dos Reis          7
# 053a. Mesquita                7
# 041a. Tanque                  6
# 072a. São Gonçalo             6
# 075a. Rio do Ouro             6
# 056a. Comendador Soares       5
# 034a. Bangu                   5
# 021a. Bonsucesso              4
# 123a. Macaé                   4
# 038a. Braz de Pina            4
# 076a. Niterói - Centro        4
# 077a. Icaraí                  4
# 050a. Itaguaí                 4
# 039a. Pavuna                  4
# 033a. Realengo                4
# 022a. Penha                   4
# 079a. Jurujuba                3
# 036a. Santa Cruz              3
# 127a. Búzios                  3
# 044a. Inhaúma                 3
# 025a. Engenho Novo            3
# 052a. Nova Iguaçu             3
# 055a. Queimados               3
# 032a. Taquara                 3
# 048a. Seropédica              2
# 074a. Alcantara               2
# 027a. Vicente de Carvalho     2
# 040a. Honório Gurgel          2
# 060a. Campos Elíseos          2
# 006a. Cidade Nova             2
# 029a. Madureira               2
# 062a. Imbariê                 2
# 063a. Japerí                  2
# 058a. Posse                   1
# 012a. Copacabana              1
# 010a. Botafogo                1
# 145a. São João da Barra       1
# 073a. Neves                   1
# 064a. Vilar dos Teles         1
# 028a. Campinho                1
# 037a. Ilha do Governador      1
# 126a. Cabo Frio               1
# 011a. Rocinha                 1
# 017a. São Cristóvão           1
# 004a. Praça da República      1
# 081a. Itaipú                  1
# 138a. Lajes de Muriaré        1
# Name: cisp, dtype: int64

# %%
pd.value_counts(dataset5['data_fato'])
#quantidade de autos por data em agosto
# Out:
# 2018-08-02T00:00:00Z    21
# 2018-08-20T00:00:00Z    17
# 2018-08-15T00:00:00Z    16
# 2018-08-16T00:00:00Z    11
# 2018-08-21T00:00:00Z    10
# 2018-08-27T00:00:00Z     8
# 2018-08-24T00:00:00Z     8
# 2018-08-09T00:00:00Z     7
# 2018-08-31T00:00:00Z     5
# 2018-08-22T00:00:00Z     5
# 2018-08-10T00:00:00Z     5
# 2018-08-26T00:00:00Z     5
# 2018-08-03T00:00:00Z     5
# 2018-08-07T00:00:00Z     4
# 2018-08-01T00:00:00Z     4
# 2018-08-29T00:00:00Z     4
# 2018-08-04T00:00:00Z     4
# 2018-08-14T00:00:00Z     4
# 2018-08-08T00:00:00Z     4
# 2018-08-28T00:00:00Z     4
# 2018-08-23T00:00:00Z     3
# 2018-08-11T00:00:00Z     3
# 2018-08-06T00:00:00Z     3
# 2018-08-13T00:00:00Z     3
# 2018-08-18T00:00:00Z     3
# 2018-08-19T00:00:00Z     2
# 2018-08-30T00:00:00Z     2
# 2018-08-12T00:00:00Z     2
# 2018-08-25T00:00:00Z     1
# 2018-08-17T00:00:00Z     1
# 2018-05-31T00:00:00Z     1
# 2018-07-31T00:00:00Z     1
# Name: data_fato, dtype: int64

# %%
dataset5.columns
# Out:
# Index(['controle', 'ano', 'mes', 'titulo_do', 'dp', 'cisp', 'data_com',
#        'data_fato', 'hora_com', 'hora_fato', 'municipio_fato', 'local', 'cor'],
#       dtype='object')

# %%
dataset6=dataset5.loc[dataset5['data_fato']=='2018-08-02T00:00:00Z']
display (dataset6)
#aqui eu tenho as cisps onde tiveram autos de resistência no dia 2018-08-02T00:00:00Z
# Out:
#           controle   ano     mes                                  titulo_do  \
# 903  03266961-2018  2018  agosto  Morte por intervenção de agente do Estado
# 904  30070281-2018  2018  agosto  Morte por intervenção de agente do Estado
# 905  30235901-2018  2018  agosto  Morte por intervenção de agente do Estado
# 906  32798971-2018  2018  agosto  Morte por intervenção de agente do Estado
# 907  55964661-2018  2018  agosto  Morte por intervenção de agente do Estado
# 908  57000261-2018  2018  agosto  Morte por intervenção de agente do Estado
# 909  58875441-2018  2018  agosto  Morte por intervenção de agente do Estado
# 910  58875441-2018  2018  agosto  Morte por intervenção de agente do Estado
# 911  58875441-2018  2018  agosto  Morte por intervenção de agente do Estado
# 912  58875441-2018  2018  agosto  Morte por intervenção de agente do Estado
# 913  58875441-2018  2018  agosto  Morte por intervenção de agente do Estado
# 914  65556771-2018  2018  agosto  Morte por intervenção de agente do Estado
# 915  65556771-2018  2018  agosto  Morte por intervenção de agente do Estado
# 916  65556771-2018  2018  agosto  Morte por intervenção de agente do Estado
# 917  65556771-2018  2018  agosto  Morte por intervenção de agente do Estado
# 918  65556771-2018  2018  agosto  Morte por intervenção de agente do Estado
# 919  75166801-2018  2018  agosto  Morte por intervenção de agente do Estado
# 920  87380481-2018  2018  agosto  Morte por intervenção de agente do Estado
# 922  02302691-2018  2018  agosto  Morte por intervenção de agente do Estado
# 923  02302691-2018  2018  agosto  Morte por intervenção de agente do Estado
# 924  02302691-2018  2018  agosto  Morte por intervenção de agente do Estado
#
#                                      dp                     cisp  \
# 903                      071a. Itaboraí           071a. Itaboraí
# 904                       050a. Itaguaí            050a. Itaguaí
# 905          Central de Garantias Norte       025a. Engenho Novo
# 906                   052a. Nova Iguaçu  056a. Comendador Soares
# 907                  054a. Belford Roxo       054a. Belford Roxo
# 908  Delegacia de Homicídios da Capital       038a. Braz de Pina
# 909                      071a. Itaboraí           071a. Itaboraí
# 910                      071a. Itaboraí           071a. Itaboraí
# 911                      071a. Itaboraí           071a. Itaboraí
# 912                      071a. Itaboraí           071a. Itaboraí
# 913                      071a. Itaboraí           071a. Itaboraí
# 914  Delegacia de Homicídios da Capital             041a. Tanque
# 915  Delegacia de Homicídios da Capital             041a. Tanque
# 916  Delegacia de Homicídios da Capital             041a. Tanque
# 917  Delegacia de Homicídios da Capital             041a. Tanque
# 918  Delegacia de Homicídios da Capital             041a. Tanque
# 919                  035a. Campo Grande           033a. Realengo
# 920               059a. Duque de Caxias    059a. Duque de Caxias
# 922                   052a. Nova Iguaçu        052a. Nova Iguaçu
# 923                   052a. Nova Iguaçu        052a. Nova Iguaçu
# 924                   052a. Nova Iguaçu        052a. Nova Iguaçu
#
#                  data_com             data_fato  hora_com hora_fato  \
# 903  2018-08-02T00:00:00Z  2018-08-02T00:00:00Z  21:11:33  16:40:00
# 904  2018-08-02T00:00:00Z  2018-08-02T00:00:00Z  15:33:01  09:00:00
# 905  2018-08-02T00:00:00Z  2018-08-02T00:00:00Z  17:00:58  12:15:00
# 906  2018-08-02T00:00:00Z  2018-08-02T00:00:00Z  17:29:52  11:00:00
# 907  2018-08-02T00:00:00Z  2018-08-02T00:00:00Z  13:41:42  04:00:00
# 908  2018-08-02T00:00:00Z  2018-08-02T00:00:00Z  14:51:20  13:00:00
# 909  2018-08-02T00:00:00Z  2018-08-02T00:00:00Z  14:33:06  09:00:00
# 910  2018-08-02T00:00:00Z  2018-08-02T00:00:00Z  14:33:06  09:00:00
# 911  2018-08-02T00:00:00Z  2018-08-02T00:00:00Z  14:33:06  09:00:00
# 912  2018-08-02T00:00:00Z  2018-08-02T00:00:00Z  14:33:06  09:00:00
# 913  2018-08-02T00:00:00Z  2018-08-02T00:00:00Z  14:33:06  09:00:00
# 914  2018-08-02T00:00:00Z  2018-08-02T00:00:00Z  16:24:35  09:00:00
# 915  2018-08-02T00:00:00Z  2018-08-02T00:00:00Z  16:24:35  09:00:00
# 916  2018-08-02T00:00:00Z  2018-08-02T00:00:00Z  16:24:35  09:00:00
# 917  2018-08-02T00:00:00Z  2018-08-02T00:00:00Z  16:24:35  09:00:00
# 918  2018-08-02T00:00:00Z  2018-08-02T00:00:00Z  16:24:35  09:00:00
# 919  2018-08-02T00:00:00Z  2018-08-02T00:00:00Z  17:01:07  08:00:00
# 920  2018-08-02T00:00:00Z  2018-08-02T00:00:00Z  03:02:11  20:30:00
# 922  2018-08-03T00:00:00Z  2018-08-02T00:00:00Z  15:17:16  21:40:00
# 923  2018-08-03T00:00:00Z  2018-08-02T00:00:00Z  15:17:16  21:40:00
# 924  2018-08-03T00:00:00Z  2018-08-02T00:00:00Z  15:17:16  21:40:00
#
#       municipio_fato        local       cor
# 903         Itaboraí  Via pública     parda
# 904          Itaguaí       Outros     parda
# 905   Rio de Janeiro  Via pública     parda
# 906      Nova Iguaçu  Via pública     parda
# 907     Belford Roxo  Via pública  ignorado
# 908   Rio de Janeiro  Via pública  ignorado
# 909         Itaboraí  Via pública     parda
# 910         Itaboraí  Via pública    branca
# 911         Itaboraí  Via pública     parda
# 912         Itaboraí  Via pública    branca
# 913         Itaboraí  Via pública     negra
# 914   Rio de Janeiro  Via pública     parda
# 915   Rio de Janeiro  Via pública     parda
# 916   Rio de Janeiro  Via pública     parda
# 917   Rio de Janeiro  Via pública     parda
# 918   Rio de Janeiro  Via pública     parda
# 919   Rio de Janeiro  Via pública     negra
# 920  Duque de Caxias  Via pública     parda
# 922      Nova Iguaçu  Via pública     parda
# 923      Nova Iguaçu  Via pública     parda
# 924      Nova Iguaçu  Via pública     negra

# %%
dataset6['cisp']
#são as cisps
# Out:
# 903             071a. Itaboraí
# 904              050a. Itaguaí
# 905         025a. Engenho Novo
# 906    056a. Comendador Soares
# 907         054a. Belford Roxo
# 908         038a. Braz de Pina
# 909             071a. Itaboraí
# 910             071a. Itaboraí
# 911             071a. Itaboraí
# 912             071a. Itaboraí
# 913             071a. Itaboraí
# 914               041a. Tanque
# 915               041a. Tanque
# 916               041a. Tanque
# 917               041a. Tanque
# 918               041a. Tanque
# 919             033a. Realengo
# 920      059a. Duque de Caxias
# 922          052a. Nova Iguaçu
# 923          052a. Nova Iguaçu
# 924          052a. Nova Iguaçu
# Name: cisp, dtype: object

# %%
br=dataset6.loc[dataset6['cisp']=='054a. Belford Roxo']
display(br)
#aqui em saparei o auto de resistência que aconteceu em Belford Roxo no dia 02 de agosto
# Out:
#           controle   ano     mes                                  titulo_do  \
# 907  55964661-2018  2018  agosto  Morte por intervenção de agente do Estado
#
#                      dp                cisp              data_com  \
# 907  054a. Belford Roxo  054a. Belford Roxo  2018-08-02T00:00:00Z
#
#                 data_fato  hora_com hora_fato municipio_fato        local  \
# 907  2018-08-02T00:00:00Z  13:41:42  04:00:00   Belford Roxo  Via pública
#
#           cor
# 907  ignorado

# %%
dataset8=dataset5.loc[dataset5['data_fato']=='2018-08-03T00:00:00Z']
display(dataset8)
# Out:
#           controle   ano     mes                                  titulo_do  \
# 921  02243691-2018  2018  agosto  Morte por intervenção de agente do Estado
# 925  21773151-2018  2018  agosto  Morte por intervenção de agente do Estado
# 926  53481041-2018  2018  agosto  Morte por intervenção de agente do Estado
# 927  55689681-2018  2018  agosto  Morte por intervenção de agente do Estado
# 928  91788381-2018  2018  agosto  Morte por intervenção de agente do Estado
#
#                                      dp                       cisp  \
# 921                        063a. Japerí               063a. Japerí
# 925          Central de Garantias Norte            029a. Madureira
# 926  Delegacia de Homicídios da Capital         038a. Braz de Pina
# 927           027a. Vicente de Carvalho  027a. Vicente de Carvalho
# 928                   072a. São Gonçalo          072a. São Gonçalo
#
#                  data_com             data_fato  hora_com hora_fato  \
# 921  2018-08-03T00:00:00Z  2018-08-03T00:00:00Z  23:20:16  17:00:00
# 925  2018-08-03T00:00:00Z  2018-08-03T00:00:00Z  20:47:00  12:50:00
# 926  2018-08-03T00:00:00Z  2018-08-03T00:00:00Z  18:32:41  07:20:00
# 927  2018-08-03T00:00:00Z  2018-08-03T00:00:00Z  19:29:33  09:00:00
# 928  2018-08-03T00:00:00Z  2018-08-03T00:00:00Z  23:02:45  16:00:00
#
#      municipio_fato        local       cor
# 921          Japeri       Outros     negra
# 925  Rio de Janeiro       Favela  ignorado
# 926  Rio de Janeiro       Favela     parda
# 927  Rio de Janeiro        Morro     parda
# 928     São Gonçalo  Via pública     negra
